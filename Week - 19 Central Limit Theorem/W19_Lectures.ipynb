# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# #Uniform Distribution

# %%
uniform_samples = (np.random.uniform(0, 1, 100000))

# %%
sns.distplot(uniform_samples, bins=10, hist=True, kde=False);

# %%
samples = [np.sum(np.random.uniform(0, 1, 100)) for x in range(10000)]

# %%
sns.distplot(samples, bins=20, hist=True, kde=True);

# %% [markdown]
# #Normal Distribution

# %%
normal_samples = (np.random.normal(0, 1, 100000))

# %%
sns.distplot(normal_samples, bins=20, hist=True, kde=True);

# %%
samples = [np.sum(np.random.normal(0, 1, 100)) for x in range(10000)]

# %%
sns.distplot(samples, bins=20, hist=True, kde=True);

# %% [markdown]
# #Discrete Distribution

# %%
discrete_samples = np.random.randint(1, 101, 100)

# %%
sns.distplot(discrete_samples, bins = 20, hist = True, kde = True)

# %%
samples = [np.sum(np.random.randint(1, 101, 100)) for x in range(100000)]

# %%
sns.distplot(samples, bins=20, hist=True, kde=True);

# %% [markdown]
# #10 Die Throws example

# %%
import plotly.express as ply
import matplotlib.pyplot as plt

# %%
MU = np.mean([x for x in range(1, 7)])
SD = np.std([x for x in range(1, 7)])

# %%
print("Mean > " + str(MU))
print("Standard Deviation > " + str(SD))
# Out:
# Mean > 3.5
# Standard Deviation 1.707825127659933

# %%
samples = [np.sum([np.random.randint(1, 7) for n in range(10)]) for k in range(10000)]

# %%
MU = np.mean(samples)
SD = np.std(samples)

# %%
print("Mean > " + str(MU))
print("Standard Deviation > " + str(SD))
# Out:
# Mean > 35.0061
# Standard Deviation 5.409275625257045

# %%
normal_samples = (samples - MU)/SD

# %%
sns.set_color_codes('bright')

# %%
plt.legend?

# %%
plt.figure(figsize = (20, 8))
sns.distplot(samples, bins=20, hist=True, kde=True, label = 'Original Distribution');
sns.distplot(normal_samples, bins=20, hist=True, kde=True, label = 'Normalized Distribution');

plt.legend(loc = 'best', fontsize = 18, fancybox = True, shadow = True)

# %%
group_labels = ['Originalplot', 'Normalplot'] # name of the dataset
hist_data = [samples, normal_samples]

fig = ff.create_distplot(hist_data, group_labels)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8d9b8770-e87e-4dd8-87a2-d321496bb2d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8d9b8770-e87e-4dd8-87a2-d321496bb2d9")) {
#                     Plotly.newPlot(
#                         '8d9b8770-e87e-4dd8-87a2-d321496bb2d9',
#                         [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Originalplot", "marker": {"color": "rgb(31, 119, 180)"}, "name": "Originalplot", "opacity": 0.7, "type": "histogram", "x": [33, 37, 31, 37, 34, 45, 31, 27, 37, 34, 25, 26, 41, 32, 28, 35, 31, 43, 30, 35, 34, 40, 36, 36, 37, 34, 30, 30, 19, 28, 30, 37, 36, 37, 36, 36, 34, 39, 37, 43, 31, 41, 37, 36, 37, 32, 41, 33, 37, 35, 22, 47, 28, 36, 35, 29, 44, 36, 33, 25, 37, 35, 38, 39, 39, 34, 33, 45, 42, 26, 43, 39, 
33, 32, 37, 33, 32, 34, 32, 49, 36, 35, 41, 33, 34, 31, 38, 23, 42, 42, 37, 34, 37, 40, 32, 24, 40, 32, 41, 40, 31, 38, 34, 36, 41, 40, 34, 33, 43, 37, 33, 45, 32, 35, 37, 35, 36, 34, 29, 37, 23, 27, 39, 27, 34, 30, 43, 41, 23, 31, 39, 39, 33, 42, 42, 35, 38, 35, 34, 35, 32, 33, 29, 34, 37, 42, 35, 27, 40, 33, 31, 37, 41, 26, 29, 39, 27, 42, 42, 32, 33, 36, 44, 30, 32, 46, 34, 32, 33, 36, 37, 35, 36, 36, 29, 38, 40, 35, 32, 43, 40, 34, 33, 38, 23, 34, 27, 36, 37, 41, 29, 29, 44, 39, 37, 34, 32, 31, 37, 32, 47, 40, 36, 31, 37, 46, 33, 30, 35, 39, 42, 40, 29, 33, 43, 29, 32, 32, 34, 27, 38, 36, 43, 32, 40, 40, 38, 32, 42, 34, 46, 36, 37, 35, 34, 29, 31, 40, 37, 32, 38, 36, 42, 30, 48, 42, 37, 30, 35, 35, 34, 26, 32, 42, 29, 31, 36, 47, 32, 38, 33, 42, 53, 35, 37, 39, 39, 28, 37, 23, 35, 33, 31, 47, 36, 36, 29, 41, 34, 32, 41, 33, 30, 30, 38, 33, 25, 28, 35, 36, 35, 32, 35, 38, 40, 40, 39, 32, 35, 29, 30, 32, 37, 34, 34, 36, 28, 36, 39, 30, 38, 28, 35, 36, 37, 29, 43, 33, 39, 44, 36, 39, 38, 41, 35, 27, 39, 35, 33, 39, 41, 34, 32, 26, 36, 46, 40, 25, 37, 30, 35, 35, 38, 27, 22, 39, 28, 37, 29, 35, 32, 38, 38, 33, 39, 38, 29, 30, 37, 32, 44, 35, 30, 36, 36, 40, 33, 32, 32, 30, 25, 35, 38, 31, 25, 33, 43, 32, 33, 33, 31, 26, 39, 43, 34, 38, 34, 38, 38, 34, 37, 35, 41, 40, 41, 39, 37, 32, 35, 42, 45, 32, 32, 33, 34, 32, 24, 39, 34, 42, 41, 32, 35, 36, 44, 38, 33, 41, 34, 34, 33, 30, 42, 30, 31, 44, 32, 36, 34, 32, 33, 29, 50, 28, 32, 29, 37, 26, 46, 39, 39, 40, 36, 46, 39, 43, 29, 33, 40, 31, 30, 39, 34, 36, 33, 37, 37, 35, 38, 38, 42, 29, 22, 28, 36, 22, 34, 31, 27,  ...

# %%
(40 - MU)/SD
# Out:
# 0.9232104899004272

# %%
from scipy import stats

# %% [markdown]
# ### Chance of getting a sum greater than 40 after 10 die throws

# %%
round(round(stats.norm.cdf((60 - MU)/SD), 3) - round(stats.norm.cdf((40 - MU)/SD), 3), 3)
# Out:
# 0.178

# %%
print(f"{round(round(stats.norm.cdf((60 - MU)/SD), 3) - round(stats.norm.cdf((40 - MU)/SD), 3), 3) * 100}%")
# Out:
# 17.8%
